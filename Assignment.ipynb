# %% [markdown]
# <a href="https://colab.research.google.com/github/elizabethts/Tuesday-June-Fourth/blob/master/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#created June 4

# %%
import pandas as pd
import seaborn as sns

# %%
filepath = 'https://raw.githubusercontent.com/elizabethts/Tuesday-June-Fourth/master/survey.csv'

# %%
survey = pd.read_csv(filepath)

# %%
survey.head()
# Out:
#                Unnamed: 0  ...            In a classroom I
# 0  Evangelista Torricelli  ...  just listen and take notes
# 1              Pythagoras  ...  just listen and take notes
# 2                 Alhazen  ...  just listen and take notes
# 3            Randy Pausch  ...  just listen and take notes
# 4                 Alhazen  ...                         NaN
#
# [5 rows x 5 columns]

# %%
sns.distplot(survey.fillna(0).iloc[:, 1]);

# %%
sns.pairplot(survey.fillna(0));
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '

# %%
#pairplot w/ Linear Regression Lines
sns.pairplot(survey, kind='reg',
            plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.1}});
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Kernel density estimation
sns.jointplot(x='What is your programming level?', y="What is your math level?", data=survey, kind="kde");
